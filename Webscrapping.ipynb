# %%
#pip install beautifulsoup4
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
from bs4 import BeautifulSoup

# %%
pip install requests
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import requests as re

# %%
#pip install pandas
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as ps

# %%
top="https://www.digit.in/top-products/top-10-smartphones-to-buy-in-india-1.html"

# %%
res=re.get(top)

# %%
res
# Out:
# <Response [200]>

# %%
text_html=BeautifulSoup(res.text)

# %%
text_html
# Out:
# <!DOCTYPE html>
# <html lang="en">
# <head>
# <meta charset="utf-8"/>
# <meta content="width=device-width,initial-scale=1" name="viewport"/>
# <meta content="on" http-equiv="x-dns-prefetch-control"/>
# <link href="https://www.digit.in/images/favicon.ico" rel="icon" type="image/x-icon"/>
# <link href="https://www.digit.in/css/top10_v3.css?v=766" rel="stylesheet" type="text/css"/>
# <link href="https://static.digit.in/" rel="dns-prefetch"/>
# <link href="https://connect.facebook.net/" rel="dns-prefetch"/>
# <link href="https://securepubads.g.doubleclick.net/tag/js/gpt.js" rel="preconnect"/>
# <link as="font" crossorigin="" href="https://static.digit.in/barlow400.woff2" rel="preload"/>
# <link as="font" crossorigin="" href="https://static.digit.in/barlow600.woff2" rel="preload"/>
# <style type="text/css">
# ...

# %%
Phone=text_html.select(".left_side h3")

# %%
Phone
# Out:
# [<h3>Samsung Galaxy S23 Ultra</h3>,
#  <h3>Apple iPhone 14 Pro Max</h3>,
#  <h3>Google Pixel 7 Pro</h3>,
#  <h3>iQOO 11 5G</h3>,
#  <h3>Samsung Galaxy S22 Ultra</h3>,
#  <h3>Vivo X80 Pro</h3>,
#  <h3>Samsung Galaxy Z Fold 4</h3>,
#  <h3>OnePlus 11</h3>,
#  <h3>Xiaomi 13 Pro</h3>]

# %%
pri=text_html.select(".lowest_price p")

# %%
pri
# Out:
# [<p>₹ 124,999</p>,
#  <p>₹ 128,099</p>,
#  <p>₹ 75,499</p>,
#  <p>₹ 59,990</p>,
#  <p>₹ 106,999</p>,
#  <p>₹ 79,999</p>,
#  <p>₹ 154,998</p>,
#  <p>₹ 56,999</p>,
#  <p>₹ 79,999</p>]

# %%
con=text_html.select(".full_width+ li .value")

# %%
con
# Out:
# [<div class="value">256GB / 12GB</div>,
#  <div class="value">128GB / 8GB</div>,
#  <div class="value">128GB / 8GB</div>,
#  <div class="value">256GB / 8GB</div>,
#  <div class="value">256GB / 12GB</div>,
#  <div class="value">256GB / 12GB</div>,
#  <div class="value">256GB / 12GB</div>,
#  <div class="value">128GB / 8GB</div>,
#  <div class="value">256GB / 12GB</div>]

# %%
phone_de=ps.DataFrame({"phone_name":Phone,"phone_price":pri,"con":con})

# %%
phone_de
# Out:
#                    phone_name  phone_price             con
# 0  [Samsung Galaxy S23 Ultra]  [₹ 124,999]  [256GB / 12GB]
# 1   [Apple iPhone 14 Pro Max]  [₹ 128,099]   [128GB / 8GB]
# 2        [Google Pixel 7 Pro]   [₹ 75,499]   [128GB / 8GB]
# 3                [iQOO 11 5G]   [₹ 59,990]   [256GB / 8GB]
# 4  [Samsung Galaxy S22 Ultra]  [₹ 106,999]  [256GB / 12GB]
# 5              [Vivo X80 Pro]   [₹ 79,999]  [256GB / 12GB]
# 6   [Samsung Galaxy Z Fold 4]  [₹ 154,998]  [256GB / 12GB]
# 7                [OnePlus 11]   [₹ 56,999]   [128GB / 8GB]
# 8             [Xiaomi 13 Pro]   [₹ 79,999]  [256GB / 12GB]

# %%
phone_de.to_csv('C:/Users/Dinesh Kumar/OneDrive/Desktop/top10.csv')
